# %% [markdown]
# ## 1. La legge dei grandi numeri
#
# La legge dei grandi numeri è un teorema fondamentale della teoria della probabilità che indica che se ripetiamo molte volte (tendendo all'infinito) lo stesso esperimento, la frequenza di un certo evento tende ad essere costante.
#
# Vale a dire, **la legge dei grandi numeri indica che se lo stesso test viene eseguito ripetutamente (ad esempio, lancio di una moneta), la frequenza con cui si ripeterà un determinato evento (testa/croce) si avvicinerà a una costante. Questa a sua volta sarà la probabilità che questo evento si verifichi.**
#
# Fonte: https://it.economy-pedia.com/11038376-law-of-the-big-numbers
#
# - Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.
# - Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# - Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random as rd

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random as rd

def simulazione_lanci(N):
    lanci = [np.random.randint(0, 2) for i in range(N)]
    return (sum(lanci) / N) * 100


numeri_lanci = list(range(1, 1001))
percentuali_testa = [simulazione_lanci(n) for n in numeri_lanci]


df = pd.DataFrame({0: numeri_lanci, 1: percentuali_testa})
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x=df[0], y=df[1], color="blue")
plt.axhline(50, color="red", linestyle="--")
plt.xlabel("numero di lanci")
plt.ylabel("percentuale di risultato=testa")
plt.title("legge dei grandi numeri")
plt.show()

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random as rd
def funzione(vec_prob, n):
    campione = np.random.choice(a=[0, 1], size=n, replace=True, p=vec_prob)
    return sum(campione)


p = [0.5, 0.5]
dimensioni = range(1, 1001)
medie = [funzione(p, n) / n for n in dimensioni]
plt.figure(figsize=(10, 5))
plt.plot(dimensioni, medie, color="blue", linewidth=1)
plt.axhline(p[1], color="red", linestyle="--")
plt.xlabel("Grandezza del campione (n)")
plt.ylabel("Numero medio di teste")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random as rd


def simulazione_lanci(N):
    lanci = [rd.randint(0, 1) for i in range(N)]
    return (sum(lanci) / N) * 100
campioni = [n for n in range(10, 20001, 200)]
risultati_campioni = [simulazione_lanci(n) for n in campioni]
ls_risultati = [
    [campioni[i], risultati_campioni[i]] for i in range(len(campioni))
]

df = pd.DataFrame(ls_risultati)

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x=df[0], y=df[1], color="blue")
plt.axhline(50, color="red", linestyle="--")
plt.xlabel("numero di lanci")
plt.ylabel("percentuale di risultato=testa")
plt.title("legge dei grandi numeri")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x=df[0], y=df[1], color="blue")
plt.axhline(50, color='red', linestyle='--')
plt.xlabel("numero di lanci")
plt.ylabel("percentuale di risultato=testa")
plt.title("legge dei grandi numeri")
plt.show()

# %% [markdown]
# ## 2. Analisi del Dataset Titanic
# - Quante righe e colonne ha il dataset?
# - Controlla quanti valori mancanti ci sono per colonna
# - Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
# - Controlla se ci sono righe duplicate
# - Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età nella colonna 'Age' riempili con il valore medio
# - Visualizza la distribuzione dell'età per classe
# - Visualizza la distribuzione dell'età per classe dividendo e mostrando insieme i dati di uomini e donne

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 📦 Caricamento del dataset
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

def imputa_eta(row):
    if pd.isnull(row["Age"]):
        return eta_media_per_classe[row["Pclass"]]
    return row["Age"]



url = (
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
)
df = pd.read_csv(url)

righe, colonne = df.shape
print(f"Il dataset ha {righe} righe e {colonne} colonne.\n")
print("Valori mancanti per colonna prima:")
print(df.isnull().sum())
print("\n")
valore_piu_frequente = df["Embarked"].mode()[0]
df["Embarked"] = df["Embarked"].fillna(valore_piu_frequente)
print(
    f"Valori mancanti in Embarked riempiti con moda: '{valore_piu_frequente}'\n"
)
valori_duplicati = df.duplicated().sum()
print(f"Numero di righe duplicate: {valori_duplicati}\n")
eta_media_per_classe = df.groupby("Pclass")["Age"].mean()
print("Età media per ogni classe di viaggio:")
print(eta_media_per_classe)
print("\n")




df["Age"] = df.apply(imputa_eta, axis=1)
print(
    "Valori mancanti in 'Age' dopo il riempimento:",
    df["Age"].isnull().sum(),
    "\n",
)
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="Pclass", y="Age")
plt.title("Distribuzione età per Classe ")
plt.xlabel("Classe di viaggio")
plt.ylabel("Età")
plt.show()
plt.figure(figsize=(10, 5))
sns.violinplot(data=df, x="Pclass", y="Age", hue="Sex", split=True)
plt.title(
    "Distribuzione   età per Classe tra Uomini e Dpnne"
)
plt.xlabel("Classe di viaggio")
plt.ylabel("Età")
plt.show()
# Out:
# Il dataset ha 891 righe e 12 colonne.
#
# Valori mancanti per colonna prima:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
#
# Valori mancanti in Embarked riempiti con moda: 'S'
#
# Numero di righe duplicate: 0
#
# Età media per ogni classe di viaggio:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64
#
#
# Valori mancanti in 'Age' dopo il riempimento: 0

# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# - Calcola la lunghezza e la larghezza media dei petali per specie
# - Visualizza le dimensioni dei petali per specie (scatterplot)
# - Crea una nuova colonna per l'area del petalo e analizzala
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
df.head()




print("--- Conteggio campioni per specie ---")
print(df["species"].value_counts())
print("\n")


print("--- Media di lunghezza e larghezza del petalo per specie ---")
medie_petalo = df.groupby("species")[["petal_length", "petal_width"]].mean()
print(medie_petalo)
print("\n")



plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df, x="petal_length", y="petal_width", hue="species", palette="deep"
)
plt.xlabel("Lunghezza Petalo (cm)")
plt.ylabel("Larghezza Petalo (cm)")
plt.title("Dimensioni dei petali per specie")
plt.legend(title="Specie")
plt.show()


df["petal_area"] = df["petal_length"] * df["petal_width"]

print("--- Analisi statistica dell'area del petalo per specie ---")
analisi_area = df.groupby("species")["petal_area"].describe()
print(analisi_area)


plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="species", y="petal_area", palette="pastel")
plt.xlabel("Specie")
plt.ylabel("Area del Petalo ($cm^2$)")
plt.title("Distribuzione dell'area del petalo per specie")
plt.show()
# Out:
# --- Conteggio campioni per specie ---
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
#
# --- Media di lunghezza e larghezza del petalo per specie ---
#             petal_length  petal_width
# species
# setosa             1.462        0.246
# versicolor         4.260        1.326
# virginica          5.552        2.026
# --- Analisi statistica dell'area del petalo per specie ---
#             count     mean       std   min     25%     50%    75%    max
# species
# setosa       50.0   0.3656  0.181155  0.11  0.2800   0.300   0.42   0.96
# versicolor   50.0   5.7204  1.368403  3.30  4.8600   5.615   6.75   8.64
# virginica    50.0  11.2962  2.157412  7.50  9.7175  11.445  12.79  15.87
# C:\Users\emanu\AppData\Local\Temp\ipykernel_6656\1274603132.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
